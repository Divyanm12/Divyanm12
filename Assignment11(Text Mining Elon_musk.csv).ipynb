# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('Elon_musk.csv', encoding='mac_roman')
df.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                           @kunalb11 I‚Äôm an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
# Create a function to clean the tweets
def cleanTxt(text):
 text = re.sub('@[A-Za-z0–9]+', '', text) #Removing @mentions
 text = re.sub('#', '', text) # Removing '#' hash tag
 text = re.sub('RT[\s]+', '', text) # Removing RT
 text = re.sub('https?:\/\/\S+', '', text) # Removing hyperlink
 
 return text

# Clean the tweets
df['Text'] = df['Text'].apply(cleanTxt)

# %%
# Show the cleaned tweets
df.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                                  11 I‚Äôm an alien
# 1           2  _AA_Carmack Ray tracing on Cyberpunk with HDR ...
# 2           3                                   Great interview!
# 3           4                          27 Doge is underestimated
# 4           5   Congratulations Tesla China for amazing execu...

# %%
# Create a function to get the subjectivity
def getSubjectivity(text):
   return TextBlob(text).sentiment.subjectivity

# Create a function to get the polarity
def getPolarity(text):
   return  TextBlob(text).sentiment.polarity

# Create two new columns 'Subjectivity' & 'Polarity'
df['Subjectivity'] = df['Text'].apply(getSubjectivity)
df['Polarity'] = df['Text'].apply(getPolarity)

# Show the new dataframe with columns 'Subjectivity' & 'Polarity'
df
# Out:
#       Unnamed: 0                                               Text  \
# 0              1                                  11 I‚Äôm an alien
# 1              2  _AA_Carmack Ray tracing on Cyberpunk with HDR ...
# 2              3                                   Great interview!
# 3              4                          27 Doge is underestimated
# 4              5   Congratulations Tesla China for amazing execu...
# ...          ...                                                ...
# 1994        1995   True, it sounds so surreal, but the negative ...
# 1995        1996   Make sure to read ur terms &amp; conditions b...
# 1996        1997                                     Samwise Gamgee
# 1997        1998   Altho Dumb and Dumber is <U+0001F525><U+0001F...
# 1998        1999                          Progress update August 28
#
#       Subjectivity  Polarity
# 0         0.750000 -0.250000
# 1         0.000000  0.000000
# 2         0.750000  1.000000
# 3         0.000000  0.000000
# 4         0.366667  0.345313
# ...            ...       ...
# 1994      0.508333  0.111111
# 1995      0.888889  0.625000
# 1996      0.000000  0.000000
# 1997      0.500000 -0.375000
# 1998      0.000000  0.000000
#
# [1999 rows x 4 columns]

# %%
# word cloud visualization
allWords = ' '.join([twts for twts in df['Text']])
wordCloud = WordCloud(width=500, height=300, random_state=21, max_font_size=110).generate(allWords)
plt.imshow(wordCloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
# Create a function to compute negative (-1), neutral (0) and positive (+1) analysis
def getAnalysis(score):
    if score < 0:
      return 'Negative'
    elif score == 0:
      return 'Neutral'
    else:
      return 'Positive'
df['Analysis'] = df['Polarity'].apply(getAnalysis)
# Show the dataframe
df
# Out:
#       Unnamed: 0                                               Text  \
# 0              1                                  11 I‚Äôm an alien
# 1              2  _AA_Carmack Ray tracing on Cyberpunk with HDR ...
# 2              3                                   Great interview!
# 3              4                          27 Doge is underestimated
# 4              5   Congratulations Tesla China for amazing execu...
# ...          ...                                                ...
# 1994        1995   True, it sounds so surreal, but the negative ...
# 1995        1996   Make sure to read ur terms &amp; conditions b...
# 1996        1997                                     Samwise Gamgee
# 1997        1998   Altho Dumb and Dumber is <U+0001F525><U+0001F...
# 1998        1999                          Progress update August 28
#
#       Subjectivity  Polarity  Analysis
# 0         0.750000 -0.250000  Negative
# 1         0.000000  0.000000   Neutral
# 2         0.750000  1.000000  Positive
# 3         0.000000  0.000000   Neutral
# 4         0.366667  0.345313  Positive
# ...            ...       ...       ...
# 1994      0.508333  0.111111  Positive
# 1995      0.888889  0.625000  Positive
# 1996      0.000000  0.000000   Neutral
# 1997      0.500000 -0.375000  Negative
# 1998      0.000000  0.000000   Neutral
#
# [1999 rows x 5 columns]

# %%
# Printing positive tweets 
print('Printing positive tweets:\n')
j=1
sortedDF = df.sort_values(by=['Polarity']) #Sort the tweets
for i in range(0, sortedDF.shape[0] ):
  if( sortedDF['Analysis'][i] == 'Positive'):
    print(str(j) + ') '+ sortedDF['Text'][i])
    print()
    j= j+1
# Out:
# Printing positive tweets:
#
# 1)   Great interview!
#
# 2)  Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
#
# 3) Happy New Year of the Ox!
#
# 4) _  10 Haha thanks :)
#
# 5) The most entertaining outcome is the most likely
#
# 6)   It‚Äôs getting real
#
# 7)  He definitely has issues, but the sentencing seems a bit high
#
# 8)  Thanks for fixing
#
# 9) This is true power haha
#
# 10) : NASA has selected Falcon Heavy to launch the first two elements of the lunar Gateway together on one mission!
#
# 11) 3  _ Once we can predict cash flow reasonably well, Starlink will IPO
#
# 12)  888 Does seem a bit high
#
# 13)   Wow
#
# 14) _7_42  So cute <U+0001F495>
#
# 15)  Extremely misleading image, as doesn‚Äôt reflect true time cost to people or rain &amp; pain
#
# 16)  It‚Äôs the most fun crypto!
#
# 17)  True
#
# 18)   Not that easy. This is two decades of intense work. Have to look at old notes, emails, texts.
#
# 19)  Have you read ? It‚Äôs great!!
#
# 20) _ Sure
#
# 21) The great thing about restaurants is that you get to hang out with strangers! - SJM
#
# 22) Much wow!
#
# 23)  _bickett   That said, the ship landing burn has a clear solution. My greate‚Ä¶
#
# 24) _  _bickett   Will still use hot gas maneuvering (RCS) thrusters,‚Ä¶
#
# 25)  _bickett   Higher Isp too
#
# 26) : Falcon 9 will launch ‚Äôs SPHEREx mission ‚Äì which will collect data on more than 300 million galaxies and explore how the un‚Ä¶
#
# 27)   It‚Äôs true!
#
# 28) _bickett    Yeah. By default, engine with least lever arm would shut down if all 3 are good.
#
# 29) No need to be a gigachad to own
#
# 30) ur welcome
#
# 31)  The most entertaining outcome is the most likely
#
# 32)  High seas &amp; wind
#
# 33) It will be filled with graffiti art
#
# 34) __  Neuralink is working super hard to ensure implant safety &amp; is in close communication with the‚Ä¶
#
# 35) : Announcing the first commercial astronaut mission to orbit Earth aboard Dragon <U+2192>
#
# 36) If you‚Äôve worked on advanced wearables, phones or robots, those skills are needed
#
# 37) Feels weird helping make (hopefully good version of) Cyberpunk come true
#
# 38)  _Cooney     Tom has some great stories about experim‚Ä¶
#
# 39) _Cooney     That sounds correct. Tom certainly deserves a lot of cre‚Ä¶
#
# 40) _Cooney     Tom is great &amp; was instrumental in developing early vers‚Ä¶
#
# 41)   T/W will be ~1.5, so it will accelerate unusually fast. High T/W is important for reusable v‚Ä¶
#
# 42)  Read the whole article <U+0001F923><U+0001F923>
#
# 43) Warm, sunny day &amp; snowy mountains
#
# 44) What a beautiful day in LA
#
# 45) 4Life I sure hope that‚Äôs not true at Tesla or SpaceX!
#
# 46)  Great shot
#
# 47) _menieb Live by the sword, die by the sword
#
# 48)   Buy &amp; hold companies that make goods &amp; produce services you love
#
# 49) With Cyberpunk, even the hotfixes literally have hotfixes, but ‚Ä¶ great game
#
# 50) 1    Shopify is great too. SpaceX used them.
#
# 51)   Indeed. The economy ‚Äî making useful products &amp; providing great services ‚Äî is what actually matters.
#
# 52)    TANSTAAFL. Would be better to have small fees than no fees, as latter makes Robin‚Ä¶
#
# 53) u can‚Äôt sell houses u don‚Äôt own
# u can‚Äôt sell cars u don‚Äôt own
# but
# u *can* sell stock u don‚Äôt own!?
# this is bs ‚Äì sh‚Ä¶
#
# 54)   Absolutely
#
# 55)  Unlike its aircraft division, which is fine, the FAA space division has a fundamentally broken reg‚Ä¶
#
# 56) The esthetics of Cyberpunk are incredible btw. The interior design is<U+0001F44C>.
#
# 57)   Major esthetics improvements coming
#
# 58) _Ryan New Roadster is part rocket
#
# 59) _Ryan   There‚Äôs more storage now &amp; easily upgradable
#
# 60) 0 to 155mph trap speed in a 1/4 mile. 200mph top speed (with right tires).
#
# 61) First production car ever to achieve 0 to 60 mph in less than 2 seconds
#
# 62)  Yup. Wild times on Discord haha.
#
# 63) I kinda love Etsy
#
# 64)  Tesla is steadily moving all NNs to 8 camera surround video. This will enable superhuman self-driving.
#
# 65)  To my surprise, Tesla has better AI hardware &amp; software than Waymo (money)
#
# 66) : Falcon 9‚Äôs first stage has landed on the Of Course I Still Love You droneship
#
# 67)  We‚Äôre switching to a more sensible FSD version numbering to distinguish between major &amp; minor updates.‚Ä¶
#
# 68)  Hopefully, early next week
#
# 69)   Given so many other companies are depending on this mission, it is getting even more scru‚Ä¶
#
# 70) Launching many small satellites for a wide range of customers tomorrow. Excited about offering low-cost access to o‚Ä¶
#
# 71)  They are part of the solution, but require lots of fresh water &amp; land. We may need something that‚Äôs‚Ä¶
#
# 72)  It‚Äôs a good path for fully renewable rocket energy, so solves part of problem, but longer chain hyd‚Ä¶
#
# 73) Am donating $100M towards a prize for best carbon capture technology
#
# 74)   _   45  7Patterson   Pretty much
#
# 75)   Absolutely! They rock. <U+0001F5A4>
#
# 76)   Tegmark is an exceptionally smart &amp; good human
#
# 77) _ The best manufacturing technology is in ultra high volume industries, like food &amp; beverage, some medical (eg syringes) &amp; toys
#
# 78) Battery cell production is the fundamental rate-limiter slowing down a sustainable energy future. Very important pr‚Ä¶
#
# 79) _ferragu Looking into this. No question that FSD should be viewed as reasonably valuable when doing a trade-in.
#
# 80)   For sure
#
# 81)  Glad you‚Äôre ok
#
# 82)  This is a good one
#
# 83) _Ryan  It will be awesome
#
# 84)  Good point
#
# 85)  Your server-side code is doing too much
#
# 86)  Happy birthday Wikipedia! So glad you exist.
#
# 87)  33 Fallout New Texas
#
# 88) 21014829 22  Good point
#
# 89) Monty Python is amazing
#
#
# 90)    They sure can twist the knife in that show!
#
# 91)   Probably wise
#
# 92)  We‚Äôre making major improvements to ease of engine swap. Needs to be a few hours at most.
#
# 93)   Nice shot
#
# 94)  We don‚Äôt have high school internships, but please apply when you‚Äôre in college!
#
# 95)  Prototypes are easy, volume production is hard, positive cash flow is  excruciating
#
# 96) : Splashdown of Dragon confirmed, completing SpaceX‚Äôs 21st _Station resupply mission and the first return of a cargo resupp‚Ä¶
#
# 97)  Detanking &amp; inspections now. Good progress towards our ‚ÄúHop in &amp; go to Mars!‚Äù goal.
#
# 98) All three static fires completed &amp; no RUDs!
#
# 99)    Wow, a lot has happened in 10 years!
#
# 100)  Fair enough haha
#
# 101)  Sea shanty tiktok takes it to a new level with actual pirate ships
#
# 102)  Sure
#
# 103)   We‚Äôre just trying to get people to Mars. Help would be appreciated.
#
# 104) : Separation confirmed! Dragon performing 3 departure burns to move away from the _Station
#
# 105)  Suicide is more than double homicide
#
# 106)  Absolutely
#
# 107)   This is an important distinction
#
# 108)  Much more than this &amp; increasing rapidly
#
# 109)  Once in a while, something happens that is even better than we imagined
#
# 110)   Probably commenting on  will do more
#
# 111)  I bought the replacement glass from a junkyard for $20. They‚Äôre great places to get spare parts.
#
# 112)  A lot of people are going to be super unhappy with West Coast high tech as the de facto arbiter of free speech
#
# 113)   Already donated to Signal a year ago. Will donate more.
#
# 114)  I am primarily trying to advance two causes: sustainable energy &amp; extending life/consciousness beyond E‚Ä¶
#
# 115)  It‚Äôs true
#
# 116) My 14-year-old son, Saxon, said he feels like 2021 will be a good year. I agree. Let us all make it so.
#
# 117)   Was also thinking that SpaceX Boca should hold fun parties and give tours for the community from time to time
#
# 118)   I super support public spaces around our production &amp; launch sites, wherever it can be done‚Ä¶
#
# 119)   That‚Äôs actually our restaurant, but SpaceX is building a futuristic bar at the top of the h‚Ä¶
#
# 120)  And increase fun! Hopefully.
#
# 121)   One of the best Tesla Solar Roof installations
#
# 122)  _feed Yes, that would be the best way to do it. A large solar field or reactor is needed for po‚Ä¶
#
# 123)  Probably less than a few dozen primary decision-makers. Technically, only three.
#
# 124)   Or at least the option for verification, so that the public can ascribe more credibilit‚Ä¶
#
# 125) Btw, critical feedback is always super appreciated, as well as ways to donate money that really make a difference (way harder than it seems)
#
# 126)  True
#
# 127)  Ya don‚Äôt say. Reminds me of this timeless classic ‚Ä¶
#
# 128)  Fast water with tiny rocks
#
# 129)  Yes, and then Occam‚Äôs razor is actually third most likely
#
# 130) The most entertaining outcome is the most likely
#
# 131)  Dumb and Dumber is a great movie tho
#
# 132) Because of the large footprint, it may seem flat, but actually ranges up to 5 stories tall
#
# 133)  Tesla is responsible for 2/3 of all the personal &amp; professional pain in my life combined. But it was worth it.
#
# 134) So proud of the Tesla team for achieving this major milestone! At the start of Tesla, I thought we had (optimistica‚Ä¶
#
# 135) : In 2020, we produced and delivered half a million cars. Huge thanks to all those who made this possible.
#
#
# 136) _ai Tesla Full Self-Driving will work at a safety level well above that of the average driver this year, of t‚Ä¶
#
# 137)  Dojo isn‚Äôt needed, but will make self-driving better. It isn‚Äôt enough to be safer than human drivers, Aut‚Ä¶
#
# 138) Great interview with Mathias D√∂pfner
#
#
# 139)  <U+0001F3A9> The Greatest Gatsby <U+0001F3A9>
#
# 140)   Rocket motion is primarily vertical, so you want the top open
#
# 141)    Production is hard, prototypes are easy. Building ~1000 Starships to create a s‚Ä¶
#
# 142) _Enough     Exactly
#
# 143)  Haha
#
# 144)    Legs would certainly work, but best part is no part, best step is no step
#
# 145)  We‚Äôre going to try to catch the Super Heavy Booster with the launch tower arm, using the grid fins to take the load
#
# 146)  Are we sure this is real?
#
# 147) All Tesla cars delivered in the final three days of the year will get three months of the Full Self-Driving option‚Ä¶
#
# 148) _Inc And Mark Dankberg. This action is wack, not dank!!
#
# 149) The Last Kingdom show is great
#
# 150) 32292601 Absolutely. Will be text &amp; visualization, but could add voice too.
#
# 151)  If they don‚Äôt love us, we‚Äôre in deep trouble!
#
# 152) _glenn True haha
#
# 153) _Inc Starlink ‚Äúposes a hazard‚Äù to Viasat‚Äôs profits, more like it. Stop the sneaky moves, Charlie Ergen!
#
# 154) _ Absolutely
#
# 155) What should Tesla do with in-car gaming in an autonomous world?
#
# 156)   Absolutely
#
# 157) Try playing Polytopia in your Tesla! Great game. Multiplayer online version coming soon.
#
# 158)  Focus on making products &amp; services people truly love, so that the total economic pie is bigger, instead of en‚Ä¶
#
# 159)  _siphiw   Roughly 95% of parts in Tesla Roadster were unique ‚Äî not in any other pro‚Ä¶
#
# 160) _feed Very important
#
# 161)   Ok, service might be able to do this. Will check.
#
# 162)  Good point
#
# 163)  _stve  Interesting
#
# 164)  Liz has always done great interviews
#
# 165) _stve  Falcon was 25% of successful orbital launches in 2020, but maybe a majority of pa‚Ä¶
#
# 166)  Vaccines are just the start. It‚Äôs also capable in theory of curing almost anything. Turns medicine into a‚Ä¶
#
# 167)    A few more revisions needed. Probably Beta 10 or 11.
#
# 168)   Sure
#
# 169)   Haha ok
#
# 170) 2823 _adri  There are subtle, important, differences between US &amp; Canada traffic rules, bu‚Ä¶
#
# 171)  Haha I will save you the nightmare of seeing me in those shorts
#
# 172) Change your horn sound to <U+0001F410>, <U+0001F40D><U+0001F3B7>, <U+0001F4A8> or holiday jingles with latest Tesla software update!
#
# 173) Merry Christmas &amp; happy holidays! <U+0001F381>
#
# 174) _com Great game!
#
# 175)  7 It will most likely make sense for Starlink to go public once the revenue growth is reasonably predictable
#
# 176) 7 Engineering, design &amp; general company operations absorb vast majority of my mind &amp; are the fundamental li‚Ä¶
#
# 177) To Tesla owners taking delivery in the final days of year, your support is super appreciated!!
#
# 178) 7 Good idea
#
# 179)  Strange, if true.
#
# - Tesla already uses iron-phosphate for medium range cars made in our Shanghai facto‚Ä¶
#
# 180) Thanks to everyone who worked so hard to make Tesla successful. My heart goes out to you.
#
# 181)  They are, although it‚Äôs kind low-key. Tesla Superchargers are being made accessible to other electric cars.
#
# 182) _saylor Are such large transactions even possible?
#
# 183)  Great game
#
# 184)  Pretty much. The main value of college used to be hanging out, having pseudo intellectual conversations &amp;‚Ä¶
#
# 185)  Absolutely. We will release FSD subscription early next year.
#
# 186) _miloslav Great nails &amp; lipstick
#
# 187)  Sounds about right
#
# 188)  _thelen Nice branding
#
# 189) Just kidding, who needs a safe word anyway!?
#
# 190) Bitcoin is my safe word
#
# 191) : Falcon 9‚Äôs first stage has landed on Landing Zone 1
#
# 192)  Pressure is slightly high in upper stage liquid oxygen tank. Review underway.
#
# 193)  Very impressive mission by China!
#
# 194)  It will get absurdly good. Tesla AI/Autopilot engineering is awesome! There‚Äôs some great AI out ther‚Ä¶
#
# 195) Star Light, Star Bright
#
# 196)  But it is visually stunning &amp; playability is good
#
# 197)  A t-shirt being better armor than a Kevlar chest plate doesn‚Äôt make sense in the absence of magic. Also, w‚Ä¶
#
# 198)  I absolutely support trans, but all these pronouns are an esthetic nightmare
#
# 199) _john  It‚Äôs a good to great game imo, but improving what may seem like mere surface detail woul‚Ä¶
#
# 200) _tesla _com Perhaps slightly more confident, but it‚Äôs essential to view this as output vs time. As‚Ä¶
#
# 201) 45  Sure hope that future doesn‚Äôt come to pass!
#
# 202) _com Giga Berlin-Brandenburg will be the first to use our new structural pack architecture, 4680 (world‚Äôs‚Ä¶
#
# 203) 2funny1  Original Deus Ex was incredible, Human Revolution was also great
#
# 204)   Yeah, briefly. Seems pretty good. I picked Nomad, so start was a little slow, but picks up‚Ä¶
#
# 205)    *cooling haha
#
# 206)    I still have a soft spot in my heart for transpiration cooking. In theory, it would us‚Ä¶
#
# 207)   Exactly! Woohoo!!
#
# 208)   SN8 did great! Even reaching apogee would‚Äôve been great, so controlling all way to putting‚Ä¶
#
# 209)  Yeah, engines did great!
#
# 210) Fuel header tank pressure was low during landing burn, causing touchdown velocity to be high &amp; RUD, but we got all‚Ä¶
#
# 211) Successful ascent, switchover to header tanks &amp; precise flap control to landing point!
#
# 212) : Success! At 1:40pm ET, 's upgraded Dragon cargo spacecraft autonomously docked to the _Station.
#
# <U+0001F409> This is the 1st‚Ä¶
#
# 213) _Station  Wow, Station looks amazing!
#
# 214) : Good morning, earthlings. <U+2600><U+FE0F> The journey continues!
#
# Watch as the NASA  cargo resupply mission docks to the _Statio‚Ä¶
#
# 215)  Carrying even more symbiotic bacteria (~40 trillion) than cells
#
# 216) : There‚Äôs something genuinely magical about seeing Starship SN8 in person. Boca Chica is beautiful, quiet and serine. T‚Ä¶
#
# 217) : Dragon separation confirmed; the spacecraft is on its way to the _station. Autonomous docking tomorrow at approximately 1‚Ä¶
#
# 218) : Falcon 9 booster has landed on the Of Course I Still Love You droneship
#
# 219)  And no toilet paper <U+0001F923><U+0001F923>
#
# 220) : The Falcon 9 booster supporting this mission previously launched  astronauts Bob Behnken and Doug Hurley to the _sta‚Ä¶
#
# 221)       Not bad
#
# 222) Much of what people think of an science is actually engineering, eg no such thing as a ‚Äúrocket scientist‚Äù, only roc‚Ä¶
#
# 223)  Thanks for everything you did to help build SpaceX! Some of the best memories ever.
#
# 224)  It will be real soon
#
# 225) 3   Static fire is not risky from build site, but we need to clear the build site for early flights
#
# 226)   Just a static fire tomorrow. Flight no earlier than Wednesday.
#
# 227) 3   Yes, very sad news. Tony was great.
#
# 228)   For a second there, I thought that was a pic of Thanos haha
#
# 229) _AA_Carmack fp16 with least important digits truncated (so it feels like fp32) is what we‚Äôre betting on for training with Dojo
#
# 230) _AA_Carmack Int8 for almost all heavy lifting in inference works great
#
# 231) Happy Thanksgiving!
#
# 232)  Haha true
#
# 233)  The Promise is greatly needed
#
# 234)  We will have special colors for new Roadster, as we did for the original
#
# 235) This is a life leader launch, so more risk than normal
#
# 236)    Yes, but only slightly filled
#
# 237) 404   This is a subject of much debate
#
# 238)   Major upgrades are slated for SN15
#
# 239)   Many small improvements, but overall similar. Wiring is more robust, engines are more mat‚Ä¶
#
# 240)  Lot of things need to go right, so maybe 1/3 chance
#
# 241) Good Starship SN8 static fire! Aiming for first 15km / ~50k ft altitude flight next week. Goals are to test 3 engin‚Ä¶
#
# 242)   Not bad! We will definitely need more engines if we make the cargo bay all propel‚Ä¶
#
# 243)  Rapid &amp; complete rocket reuse, low cost propellant, orbital refilling &amp; propellant production at d‚Ä¶
#
# 244)    We‚Äôre still far from simply video in, control out. The biggest game-changer, cu‚Ä¶
#
# 245)   FSD Beta 5 coming out in a few days. Improvement should be significant.
#
# 246)  Exciting mission!
#
# 247) 13031925  Wow
#
# 248) Tomorrow will be the 7th flight of this rocket, landing on droneship Of Course I Still Love You
#
# 249) 1  @28delayslater Sure
#
# 250)   True
#
# 251)  7  We have quiet a queue of products to build! Better do new Roadster at some point<U+0001F62C>.
#
# 252) 7  Tesla is a vehicle for creating &amp; producing many useful products
#
# 253)  7 Because I am not an investor. Tesla is definitely not the only good company, but investing is n‚Ä¶
#
# 254)  Cool
#
# 255) _Fonseca _Station   They‚Äôre moving at ~25 times the speed of sound, but it feels like nothing
#
# 256)     _Station It will be better than human vision by quite a margin
#
# 257)    _Station Exactly
#
# 258)   This is a misperception. SpaceX developed &amp; continues to use lidar for Dragon docking with‚Ä¶
#
# 259)   One day we will fly you on Starship
#
# 260)    Andrej is awesome, but it should be said that we have a very talented Autopilot‚Ä¶
#
# 261)  They have an old version of our software &amp; don‚Äôt have our NN inference computer
#
# 262)  Wild times!
#
# 263)  Change out a few parts, otherwise fine
#
# 264)  Caution strongly advised with SPACs
#
# 265)    Sure
#
# 266)   Haha sexy cropping champion of all time
#
# 267)   If next week‚Äôs release looks good, we will widen beta
#
# 268)  Next week‚Äôs release is special. Lot of fundamental improvements, both important bug fixes &amp; entire n‚Ä¶
#
# 269)   13 years &amp; $11 billion ‚Ä¶ wow
#
# 270) _   Safety is our primary design goal
#
# 271)  Let the Martians decide their own future
#
# 272)  Terraforming will be too slow to be relevant in our lifetime. However, we can establish a human base‚Ä¶
#
# 273)    That is certainly the intention!
#
# 274)  The only publicly traded stock I own is Tesla
#
# 275)  Wise words from Bogle. The point of companies is products &amp; services. They have no point in &amp; of thems‚Ä¶
#
# 276)  Life in glass domes at first. Eventually, terraformed to support life, like Earth.
#
# 277) _xD  I was going to say ‚ÄúSim!‚Äù, but that seemed too obvious haha
#
# 278)  So many things you want &amp; some you didn‚Äôt know you wanted
#
# 279)  There is such a thing as too much sentience
#
# 280)   More like he gave it his blessing. It was sort of a groundswell of those who believed‚Ä¶
#
# 281)   11742 Yeah, looks like marginal cost of launch will be less than $1M for more than 1‚Ä¶
#
# 282)   11742 Exactly
#
# 283)  11742 Merlin is a strong local maximum design, but kerosene is suboptimal fuel, no matter what‚Ä¶
#
# 284)  _bickett _Enough  11742 Yes, but from a visiting American. Ah, the irony is just too much!!
#
# 285)  4S1  Maybe making some notable changes. Will wait until figurative &amp; literal dust settles.
#
# 286) _Enough  11742 Pretty close. Definitely feel <U+0001F4AF> if I take DayQuil. Frankly, this was one‚Ä¶
#
# 287) 4S1  About 2 secs after starting engines, martyte covering concrete below shattered, sending blades of‚Ä¶
#
# 288)  11742 The most amazing thing about rocket engines is that they *sometimes* don‚Äôt blow up! The‚Ä¶
#
# 289)    11742 Absolutely. Production/testing of rocket engines is over 90% of‚Ä¶
#
# 290) 688 1   Maybe *I* just love irony haha
#
# 291)  1   They‚Äôre on their way! Hopefully, more Teslaquila next month.
#
# 292) _NSF Special permission received from Stonecutters Guild!
#
# 293)  11742 Damn, that‚Äôs not easy! I spent quite a bit of time looking at Russian/Ukrainian engines. They‚Äôre good.
#
# 294) : Docking confirmed ‚Äì Crew Dragon has arrived at the _station!
#
# 295) : <U+0001F409> Enter the Crew Dragon. At 4:48 p.m. EST (9:48 p.m. UTC), the NASA  Crew-1 astronauts give you a LIVE tour of their space‚Ä¶
#
# 296) _lab Creating synthetic mRNA for cures/vaccines is the future of medicine imo. Turns it (mostly) into a‚Ä¶
#
# 297) _anne _Skeptic  _herbers Haha
#
# 298) _lab Great thread
#
# 299)  I‚Äôm ok, thanks for asking. No symptoms for past few days, apart from fatigue. Unless something chang‚Ä¶
#
# 300) : Dragon is the only spacecraft currently flying capable of returning significant amounts of cargo to Earth and is the first priv‚Ä¶
#
# 301) : LIVE NOW: We are ready to LaunchAmerica. Are you? <U+0001F680>
#
# Watch coverage of the NASA  Crew-1 mission. Liftoff is at 7:27pm ET:‚Ä¶
#
# 302) : Watch Falcon 9 launch Crew Dragon on its first operational mission to the _station with astronauts on board <U+2192>
#
# 303)  Ok
#
# 304) : All systems are go for tonight‚Äôs launch at 7:27 p.m. EST of Crew Dragon‚Äôs first operational mission with four astronauts on boa‚Ä¶
#
# 305)     Yeah, I feel pretty normal. No symptoms right now. Last week, I had sym‚Ä¶
#
# 306) _Soichi: SpaceX NASA Crew1 just finished final dress rehearsal, getting ready for Saturday launch! Behind me is "real" Dragon‚Ä¶
#
# 307) _lab It would be great if labs could give people this level of granular feedback in their results
#
# 308) _lab:  Great question! It‚Äôs more complex question and depends on why the test is being used - ie: do you want to kn‚Ä¶
#
# 309) Worth reading this thread if you‚Äôre curious about rona testing
#
# 310)  Cool, but please be super cautious. Expect two steps forward, one back. Lot of new code was merged.
#
# 311)  Am getting wildly different results from different labs, but most likely I have a moderate case of covid‚Ä¶
#
# 312) Laws of thermodynamics:
# 1. You can‚Äôt win
# 2. You can‚Äôt break even
# 3. You can‚Äôt stop playing
#
# 313) _nunez  Interesting. My Thursday night saliva sample came back today with N1 gene (unique to cov‚Ä¶
#
# 314)  74  This seems accurate
#
# 315) _H  _roi 65 Heneghan makes a lot of sense. Hilarious that he has to clarify that he r‚Ä¶
#
# 316) _H _roi 65 This a great reference! Worth a read.
#
# 317)  Fwiw, lab I just spoke to thinks below 30 is accurate, 30 to 40 gets dicey &amp; above 40 is bs. Will talk to‚Ä¶
#
# 318)   Just spoke directly to a testing lab. Their main PCR search is for the N1 gene, unique‚Ä¶
#
# 319)  Moreover, lower the true prevalence, the higher the false positive number will be. This sounds obvious,‚Ä¶
#
# 320) _e_morgan Sure is
#
# 321)  Interesting
#
# 322) _beans  Interesting
#
# 323) What is the general population (no knowledge of symptoms) accuracy of a sars-cov2 PCR test &amp; is it possible to gene‚Ä¶
#
# 324)   A good PCR test should identify if I have the cov2 spike proteins, although I have heard s‚Ä¶
#
# 325)   Mild sniffles &amp; cough &amp; slight fever past few days. Right now, no symptoms, although I did take NyQuil.
#
# 326)  Technically, I tested positive, then negative twice, then positive again, so ‚ÄúElon Musk Tests Negati‚Ä¶
#
# 327)  Exactly
#
# 328) 45 Burst disk worked, so vehicle appears to be ok. We‚Äôll have to swap out at least one of the engines.
#
# 329)   45 Maybe melted an engine preburner or fuel hot gas manifold. Whatev‚Ä¶
#
# 330) : Tesla tops list of 2020‚Äôs Most Attractive Employers for US engineering students
#
#
# 331) 4 Astronauts fly to _Station on Sat night from Cape. First operational flight of Crew Dragon.
#
# 332)  Luck is the best superpower
#
# 333) Such a privilege to work with people I like &amp; respect so much. I feel blessed.
#
# 334)   Happy to see this :)
#
# 335)   I do expect this to become an important product for the world, but probably not financially material for Tesla
#
# 336) : Rumor has it that "Austin Chalk" is geologically one of best soils for tunneling. Want to find out? Austin jobs now avai‚Ä¶
#
# 337)   Thanks to a lot of great Autopilot/AI hardware &amp; software engineers at Tesla!
#
# 338)  For sure
#
# 339)   Will be worth it
#
# 340)  Exactly
#
# 341) 3Owners  Sure
#
# 342) 42698392  Chip has temp sensor &amp; automatically maintains safe temp
#
# 343) _Inc China understands the profound importance of reusability. The era of expendable rockets will soon be over.
#
# 344)  Good explanation. 4D is essential for dynamically occluded objects, especially in large intersection‚Ä¶
#
# 345)  Just looking for problem-solvers who get things done with a high sense of urgency. Don‚Äôt care if or where they went to school.
#
# 346) When sending your resume, please describe a few of the hardest problems you solved &amp; exactly how you solved them
#
# 347) A New Banner is needed
# Neither hard left nor right
#
# 348)  Another fine day in the simulation ‚Ä¶
#
# 349)  Maxwell was amazing. Should have more recognition. Tesla Motors, Inc., was almost called Faraday, as it to‚Ä¶
#
# 350) 420 is ten times better than 42
#
# 351) : Deployment of GPS III-4 confirmed
#
# 352) : Falcon 9‚Äôs first stage lands on the Of Course I Still Love You droneship
#
# 353)  Einstein was great, but did not succeed at engineering (and he tried)
#
# 354)  Yeah, that will be relatively easy, as so few users out in the ocean
#
# 355) _Enough 4 13031925  Yes, although I didn‚Äôt expect the stock to rise so much so‚Ä¶
#
# 356)   Super appreciate your support, Steve! That convertible loan gave us 6 months of runway.‚Ä¶
#
# 357)  Lowering Starlink terminal cost, which may sound rather pedestrian, is actually our most difficult technical challenge
#
# 358)  Right now, it takes about 5 mins to set up, but, with future improvements, probably less than 3 mi‚Ä¶
#
# 359) _arne  Canada and Norway are next after we get US out of early beta!
#
# 360) _rassett Lower latitude states need more satellites in position, so probably January
#
# 361) Several thousand more Starlink beta participation invitations going out this week
#
# 362)  New design is better with many minor tweaks. Even the small details matter.
#
# 363) _feed Haha
#
# 364) Very close to actual expected flight!
#
# 365) _Lockyer I could not be more excited about the new supercollider! That said, while it is considerably larger,‚Ä¶
#
# 366)  8 This is what matters most
#
# 367)    Understanding exactly how the body flaps control pitch, yaw &amp; roll duri‚Ä¶
#
# 368)   But, a RUD right off launch pad is also possible. Fortunately, SN9 is almost ready.
#
# 369)   Stable, controlled descent with body flaps would be great. Transferring propellant‚Ä¶
#
# 370)   We measure this primarily in intervention probability. This update addressed several issu‚Ä¶
#
# 371)  Thanks to a great Autopilot/AI team working super hard!
#
# Doing ‚Äúneural nets‚Äù without testing them again‚Ä¶
#
# 372)  Latency will improve significantly soon. Bandwidth too.
#
# 373)  This build should be noticeably better with interventions
#
# 374)   I‚Äôve spent more than half my life in California &amp; love the state. But, frankly, I think‚Ä¶
#
# 375)  And ‚Ä¶ Sweden is still right with zero deaths Oct 29
#
# 376)  True. Also, fewer heart attacks, as way easier to pump blood in 37% gravity.
#
# 377) 24 6Prince _feed Now we‚Äôre talking. Also, Stephenson 2-18 is in the constellation Scrotum haha.
#
# 378)  Accurate
#
# 379) 74  Some challenges with high winds. Looks like Sunday for static fire.
#
# 380)  Great shot!
#
# 381) Truth be told, I‚Äôve eaten at JitB many times over the years, even the teriyaki bowl
#
# 382) Wow, this mayo sure is salty!
#
# 383)   Max Payne was great on many levels. Silent Hill good too.
#
# 384)   One of the best games ever
#
# 385)   FEAR 1 with modern graphics &amp; sound would rock
#
# 386) @1matthewgarcia  Ok :)
#
# 387)   All games in this thread are far scarier &amp; more creatively so than any horror movie
#
# 388)  FEAR 2 is best imo. Also Dead Space 2. They will haunt your dreams.
#
# 389) 305  To the best of my knowledge, literally zero equipment was usable without major repairs or upgra‚Ä¶
#
# 390)  And there were actually zero employees in the factory after GM/Toyota left. They took all good equipment &amp;‚Ä¶
#
# 391)  Tesla team has done great work!
#
# 392)   Yes, very helpful. Thanks all beta testers!
#
# 393)  Video training &amp; inference is essential for excellent autonomy
#
# 394) _feed Sigh ‚Ä¶ there should be a new supersonic jet, this time electric
#
# 395) _  Sure, it could be an option in settings
#
# 396)  Visualization will tone down significantly for production. These are intentionally strident colors.
#
# 397)   45  Sure
#
# 398)  45  Good point. Probably next week in form of a written piece on SpaceX website.
#
# 399) 45  Great pics! That we now have the beginnings of a Starship production system is most meaningful.
#
# 400) _sanders Working on it. Also needs to be able fart at other cars on command.
#
# 401) 45 There will be a 360 deg glass Star Bar (name tbd) at top of high bay
#
# 402) _Ryan Well, we have said many times that the price will rise as the product functionality improves. How much ti‚Ä¶
#
# 403)  Sure
#
# 404) Now that Tesla FSD beta is out in limited release, FSD price (new or upgrade) will go up by ~$2k on Monday
#
# 405)    _raj As soon as we complete testing &amp; regulators approve. So many differe‚Ä¶
#
# 406)  _raj Haha
#
# 407)  Dependent on proving high safety
#
# 408) Starship nosecone, high bay &amp; tiki bar
#
# 409)  Got a little melty tbh :)
#
# 410) Data from 3 engine Starship static fire this morning looks good. Proceeding with nosecone mate.
#
# 411)   Firmware is probably a slightly more accurate description, but yes
#
# 412)    Mobi-C has too much mobility, fusion has too little. We need Mobi-D haha.
#
# 413)  Pretty accurate. It‚Äôs not so much DNA sequencing as it is using synthetic DNA/RNA to fix bugs in our code‚Ä¶
#
# 414)  London to Beijing would be cool
#
# 415)  Wow, that would be quite a trip!
#
# 416)  That‚Äôs my kid haha
#
# 417) _com Current production is slightly better
#
# 418)  Very creative
#
# 419)  That free fusion reactor in the sky conveniently converts ~4 million tons of mass into energy every second‚Ä¶
#
# 420)   Also, system should autodelete old data automatically by default
#
# 421)  Starting production on 7 seater next month, initial deliveries early December
#
# 422)      It‚Äôs still there, but focus is Vegas &amp; Prufrock, our new tunneling machine
#
# 423)     For sure
#
# 424)  Sweet ‚Ä¶
#
# 425)  Nice
#
# 426) ‚ÄúWhat is love? Baby don‚Äôt hurt me.‚Äù‚Äî Winston Churchill
#
# 427)   Or maybe 2 weak turrets to allow more strategic degrees of freedom
#
# 428) : This will be the first flight of the upgraded cargo version of Dragon, which is able to carry 50% more science payloads than th‚Ä¶
#
# 429) : The Dragon spacecraft supporting SpaceX‚Äôs 21st cargo resupply mission to the _station departed our Hawthorne factory last‚Ä¶
#
# 430) _at_life  Diess is doing his best to move in the right direction, but he‚Äôs in a tough position wi‚Ä¶
#
# 431)  With FSD, we got stuck in a lot of local maximums, which wasn‚Äôt clear until we hit the ceiling. This time, it‚Äôs right.
#
# 432)  @28delayslater Thank you, much more accurate haha
#
# 433)  Limited FSD beta releasing on Tuesday next week, as promised. This will, at first, be limited to a s‚Ä¶
#
# 434)  Accurate analysis. Quite a few
# ego/intelligence&gt;&gt;1 people in your comment thread haha. Neither MobilEye‚Ä¶
#
# 435)  _      Glad Jen is safe!
#
# 436)   Wow
#
# 437)  Uh ok, here we go ‚Ä¶
#
# 438)  I don‚Äôt think this is accurate
#
# 439) _nafnlaus Exactly. He plays the ‚Äúpoor inventor‚Äù card, but was rich all along &amp; invented nothing (as far as I kn‚Ä¶
#
# 440) _nafnlaus There are sketchy edits to Tesla wiki that whitewash Eberhard‚Äôs problems/glorify his role. Pretty odd‚Ä¶
#
# 441)  Interesting
#
# 442) : ‚ÄúThe future of cars can and will be electric if the entire industry starts making and marketing compelling EVs for everyone‚Ä¶
#
# 443)  I have that exact art on the wall of the place I stay in Boca Chica!
#
# 444)   Yes, failure to protect nursing homes was a major mistake (happened in most countries‚Ä¶
#
# 445)  Sweden was right
#
# 446)  Great work by SpaceX valve engineering &amp; production!
#
# 447) _AA_Carmack Compilers need to improve imo. Most type, pointer (or other memory) problems can be detected at comp‚Ä¶
#
# 448)   I‚Äôm proud to say that that nose is pointier than it needs to be haha
#
# 449)  Yeah, it‚Äôs not a contest. Advanced casting crushes best-case 3D printing, but casting doesn‚Äôt work wel‚Ä¶
#
# 450) _FarmerBob _Pettit   Great pics!
#
# 451)  Additive manufacturing of parts is still far too costly for cars, but can rapidly create tooling to accel‚Ä¶
#
# 452)     Pretty much, but I think it may end on a high note
#
# 453) : Starman, last seen leaving Earth, made its first close approach with Mars today‚Äîwithin 0.05 astronomical units, or under 5 mill‚Ä¶
#
# 454) 2  Meant to say that it should be fixed in the latest wide release. Won‚Äôt need to wait for FSD.
#
# 455)    Yes, we will play sexy snake jazz <U+0001F923>
#
# 456)  Waymo is impressive, but a highly specialized solution. The Tesla approach is a general solution. The lat‚Ä¶
#
# 457)      Great render. Note, there will need to be an arm‚Ä¶
#
# 458) _Enough  Autopilot team is making great progress. Reality sure is complicated!
#
# 459) 3  2908   We do have giant steel balls haha
#
# 460)  2908   Mass ratio. Liquid oxygen is much denser than liquid m‚Ä¶
#
# 461)  _avoigt _zimon  Had the most amazing kebab ever just outside of Tacheles. Too‚Ä¶
#
# 462)    You‚Äôre most welcome!
#
# 463) 2908   High bay should be finished (except for the giant gantry crane) within‚Ä¶
#
# 464)  247  Yes, the Gigafactory is the hardest &amp; most critical product
#
# 465) 247  But now we understand production much better. It will be our primary competitive advantage long-term.
#
# 466)   Bringing a new product to volume production is 1% inspiration &amp; 99% perspiration. You do st‚Ä¶
#
# 467)  Prototypes are a piece of cake, but high volume production of a new technology is extremely hard. Ta‚Ä¶
#
# 468)  I do so wish that more companies would put down their spreadsheets for a moment and focus on making‚Ä¶
#
# 469)  _ua    _Seeley 7 bar absolute, which is fine for‚Ä¶
#
# 470)    _Seeley One of the best shots ever!
#
# 471)   Much sooner
#
# 472)   @45thSpaceWing  Great photo!
#
# 473)  Once these satellites reach their target position, we will be able to roll out a fairly wide public beta in‚Ä¶
#
# 474) : Deployment of 60 Starlink satellites confirmed
#
# 475)   We‚Äôre not seeing notable differences yet. I think the boosters could probably do 100+ reflig‚Ä¶
#
# 476) 5 minutes from launch. Looks good so far.
#
# 477)  It‚Äôs a step in the right direction, but they should really aim for full reusability by 2026. Larger ro‚Ä¶
#
# 478)   One of my favorite writers. Foundation is tough to make into a movie, but has outstanding potential.
#
# 479) Rewatched Young Frankenstein this weekend. Still awesome. Ovaltine?
#
# 480)  The remake has the potential to be great. I kinda liked the original tbh, but it‚Äôs possible to take it up a level.
#
# 481) Hollywood should just start with the sequel &amp; skip the original, because financials
#
# 482)  This article is wildly incorrect about lithium battery costs by a factor of 5 or more presently &amp; 10X long-term
#
# 483)        Pretty wild,‚Ä¶
#
# 484) New SpaceX droneship will be called ‚ÄúA Shortfall of Gravitas‚Äù
#
# 485) Nothing can escape gravity, not even black holes (and they really tried!)
#
# 486) _AA_Carmack Would be cool to put yourself in the mind of the car while it‚Äôs driving
#
# 487) Call of Booty, great game
#
# 488)   Unexpected pressure rise in the turbomachinery gas generator
#
# 489)   All of that and more. We‚Äôre doing a broad review of launch site, propulsion, structures, av‚Ä¶
#
# 490)   Exactly
#
# 491) 4160775    Glad you‚Äôre ok!
#
# 492)   Haha
#
# 493)     Thanks for waiting!
#
# 494)    Next year for sure
#
# 495)  _M_Brown        Great
#
# 496)       Average latency will improve as more sat‚Ä¶
#
# 497)         Very s‚Ä¶
#
# 498)      Great letter! It will be increasingl‚Ä¶
#
# 499)    Glad to hear your Mom is ok
#
# 500)      Good to see. Inspiring for future of space!
#
# 501) _teslagirl 3Owners  _energy _Plasma  The new heat pump in Model Y is what re‚Ä¶
#
# 502)       Great render! The circumferentia‚Ä¶
#
# 503)  _energy _Plasma  It‚Äôs cool &amp; for sure can &amp; should be done, but I suspect its best cas‚Ä¶
#
# 504) 45 Weld esthetics will improve greatly in upcoming Starships
#
# 505)  Haha true. Why do showers have such a wide range!?
#
# 506)   Light is not as fast as you‚Äôd think
#
# 507) : SpaceX training of astronauts that will fly on board Dragon‚Äôs first operational mission is complete! When the crew arrives for‚Ä¶
#
# 508) : After launch of Crew Dragon‚Äôs first operational mission with astronauts on board, SpaceX will launch its 21st cargo resupply mi‚Ä¶
#
# 509)  Maybe we used too many magenta spotlights
#
# 510)    Fate loooves irony haha
#
# 511)   Glad SpaceX could help! We are prioritizing emergency responders &amp; locations with no Internet connectivity at all.
#
# 512) 45 True
#
# 513)   Seven years for sure to 30M+ new fully electric vehicles per year, six years maybe. Five ye‚Ä¶
#
# 514)   Both will do original cars
#
# 515)  _kerle New version coming soon
#
# 516)  Totally up to you, but if you head to a Tesla delivery center near you &amp; maybe help out new owners, that would be cool
#
# 517) _AA_Carmack Completely agree
#
# 518) Thanks Tesla Team for great work on deliveries! For new owners, we super appreciate accommodating us on delivery ti‚Ä¶
#
# 519)   45  Mostly 304L, some 301. Broke at 301 to 304 interface. SN9 will‚Ä¶
#
# 520)  We just need enough height to test body flaps &amp; drawing propellant from headers vs main tanks. Will do se‚Ä¶
#
# 521) First flight is to 15km or ~50,000 ft
#
# 522)  Sure
#
# 523)  True
#
# 524) : Falcon 9 will launch ‚Äôs super cool Interstellar Mapping and Acceleration Probe (IMAP), which will help researchers better‚Ä¶
#
# 525)   Not bad
#
# 526) _nafnlaus  Exactly
#
# 527)  Turns out they mostly press the letter s &amp; <U+0001F4A9> on the typewriter <U+0001F923>
#
#
# 528)   Haha
#
# 529) 60 Something appealing about Hawking/Hartle idea, but I agree with Turok/Feldbrugge/Lehners
#
# 530)  60 True
#
# 531)   There are some practical size constraints too. Can‚Äôt be too big to fit in the engine comp‚Ä¶
#
# 532)  Preburners ignite, then main chamber
#
# 533) : Completed a full duration test fire of the Raptor Vacuum engine at SpaceX‚Äôs rocket development facility in McGregor, Texas http‚Ä¶
#
# 534)  Haha true
#
# 535)   Jets are so cool
#
# 536)    Pretty much
#
# 537) 85  Haha
#
# 538)   Roadster will be better
#
# 539)   Thanks for your many years of support through very tough times!
#
# 540) _Enough  We will be a little below that this year (most challenging year we‚Äôve ever had), but‚Ä¶
#
# 541)  That‚Äôs about right. Maybe a little faster.
#
# 542)    Haha
#
# 543) The extreme difficulty of scaling production of new technology is not well understood. It‚Äôs 1000% to 10,000% harder‚Ä¶
#
# 544)   Haha
#
# 545) Important note about Tesla Battery Day unveil tomorrow. This affects long-term production, especially Semi, Cybertr‚Ä¶
#
# 546)  Thanks!
#
# 547) 85   We really need better legs for Starship. They‚Äôre coming.
#
# 548) 85   Most likely, all flaps will fold after landing to reduce wind tip over force. T‚Ä¶
#
# 549) 3Owners Fine, we‚Äôll do it already <U+0001F600>
#
# 550)   Good analysis, although I think we should wait until FSD is a bit more mature
#
# 551) __surfer I‚Äôm pretty sure Tesla could do a much better autocorrect. The bar is so low haha.
#
# 552) 4 _Fot_Pik  _AA_Carmack True
#
# 553)   _AA_Carmack Custom ultra high speed bus &amp; efficient cooling
#
# 554)  305  _AA_Carmack Ok
#
# 555)   _AA_Carmack Pretty much any machine-learning
#
# 556) _Fot_Pik  _AA_Carmack Sure
#
# 557)  _AA_Carmack Dojo uses our own chips &amp; a computer architecture optimized for neural net training, not a‚Ä¶
#
# 558) 35079089 _AA_Carmack  You really want waypoints this much?
#
# 559) _AA_Carmack For Dojo, we‚Äôre betting on FP16 with floating floating point (essentially, truncating mostly zeroes)‚Ä¶
#
# 560)  15 Shaped like a diamond &amp; aligned on true north
#
# 561) A prior track record of exceptional achievement in engineering *is* required, but *no* prior experience working on‚Ä¶
#
# 562)  To be frank, in the early days, I thought there was &gt;90% chance that both SpaceX &amp; Tesla would be worth‚Ä¶
#
# 563)  Irrational is such a funny word to describe numbers
#
# 564) of course I still love you
#
# 565)   Sure, but which planet?
#
# 566)  Good movie
#
# 567)  Current was too strong for droneship to hold station. Thrusters to be upgraded for future missions.
#
# 568) Speedrunning Factorio in real life ‚Ä¶
#
# 569)  No, but you make some great points. Important to note that iron‚Äôs cost advantage is partly offset by‚Ä¶
#
# 570)  Great idea!
#
# 571) _AA_Carmack  A bit more obscure, but Starhammer &amp; Stainless Steel Rat
#
# 572) _feed At first, I thought that was a parrot
#
# 573) Tunnels under cities with self-driving electric cars will feel like warp drive
#
# First operational tunnel under Vega‚Ä¶
#
# 574)  For sure
#
# 575)   Good point
#
# 576)   Good analysis
#
# 577)  Exactly
#
# 578)  Gary the snail is still winning, but we‚Äôre gaining on him/her
#
# 579)  Tunnels are the solution to traffic. You can have as many levels as you want. Usable tunnel depth far e‚Ä¶
#
# 580)  Pretty accurate simulation, although SN8 will use 3 Raptors. If SN8 craters, SN9 &amp; SN10 are close behind‚Ä¶
#
# 581)  Couldn‚Äôt agree more ‚Äî major software improvements are already in place to extend its life &amp; more coming
#
# 582) _feed Seems like they should make a whole outfit out of that material
#
# 583)  Ancient Greece had it all &amp; then committed suicide. Nobody digs your grave better than yourself.
#
# 584)   True
#
# 585)  The LEGO Movie was awesome
#
# 586)  The Story of Civilization. First book is a little dry, but second book, The Life of Greece, is incredible.
#
# 587)  I‚Äôm wearing your F-1 engine shirt right now!
#
# 588)  @_rykllan     That‚Äôs the number that really matters
#
# 589) One way or another, excitement guaranteed! Support of greater Boca, Padre, Brownsville community is very much appreciated.
#
# 590) SN8 Starship with flaps &amp; nosecone should be done in about a week. Then static fire, checkouts, static fire, fly to 60,000 ft &amp; back.
#
# 591)    Exactly. Problems like that have been addressed.
#
# 592)   Yes. Good insight.
#
# 593)    Much
#
# 594)   Releasing private beta in 2 to 4 weeks, public beta (early access owners who opt in‚Ä¶
#
# 595)  And this still isn‚Äôt using the dramatically better ‚Äú4D‚Äù (aka simultaneous surround video from 8 cameras) architecture
#
# 596) _Bass3d   Cool
#
# 597) Many exciting things will be unveiled on Battery Day 9/22 <U+26A1><U+FE0F>
#
# 598)  We will make super efficient home hvac with hepa filters one day
#
# 599)   If Reich actually cares about global warming, why is he making so much hot air!?
#
# 600) Bitte arbeiten Sie bei Tesla Giga Berlin! Es wird super Spa√ü machen!!
#
# 601)  Try a Tesla &amp; you‚Äôre welcome to give it back if you decide you prefer a Subaru
#
# 602)  Vera Rubin Observatory is cool
#
# 603)   Munger is right
#
# 604)  Black-Scholes formula is kinda bs. Big difference between a finance approximation &amp; fundamental physics / pure math.
#
# 605)  True
#
# 606)  Tesla is best understood as a collection of about a dozen startups, mostly in series, increasingly‚Ä¶
#
# 607)  Tesla R&amp;D productivity is exceptionally good due to the caliber of engineering talent
#
# 608) Tesla Model S &amp; X have hospital-grade (HEPA) air filters. 3 &amp; Y are really good too. This has a big effect on healt‚Ä¶
#
# 609) : Tesla Energy ramps hiring at Giga New York for accelerated solar production
#
#
# 610) : Onboard camera view of Falcon 9‚Äôs SAOCOM 1B launch and first stage land landing
#
# 611)    We‚Äôre pretty close to the manufacturing size limit for a milled copper &amp; steel ja‚Ä¶
#
# 612)  Haha
#
# 613)   This is a test engine. Flight articles are fixed with no gimbal.
#
# 614)  Worth noting that thrust is only slightly higher with the big bell nozzle version. Larger bell is primarily‚Ä¶
#
# 615) : The first Raptor Vacuum engine (RVac) for Starship has shipped from SpaceX‚Äôs rocket factory in Hawthorne, California to our dev‚Ä¶
#
# 616) Model 3 rated as most reliable car
#
# 617) Turns out you can make anything fly haha
#
# 618)   Exactly. This is not fully appreciated.
#
# 619) 45 Starship SN6 flew asimilar hop to SN5, but it was a much smoother &amp; faster operation
#
# 620) Great trip to Germany. Support from government &amp; people is super appreciated!
#
# 621) : Deployment of 60 Starlink satellites confirmed
#
# 622)   Trust ur butt haha
#
# 623) _Alarms Just go through resonant modes fast. It‚Äôs when you hang out there that problems arise.
#
# 624) : Falcon 9 first stage lands at Landing Zone 1 to complete this booster‚Äôs fourth flight
#
# 625) _Lockyer   If you ever want to build a long accelerator tunnel, straight or circular, I know some people ‚Ä¶
#
# 626) : After launching SAOCOM 1B and two rideshare payloads to orbit, Falcon 9‚Äôs first stage returns to Earth and lands at Landing Zon‚Ä¶
#
# 627) : Deployment of SAOCOM 1B confirmed
#
# 628) : Falcon 9‚Äôs first stage has landed at Landing Zone 1
#
# 629)  Cool
#
# 630)   If some company has solved a useful thing that we can just buy, that would be great! It‚Äôs‚Ä¶
#
# 631) _feed Technically, James Watt measured a pony, added 50% &amp; rounded up haha
#
# 632)  Wow, I super loved astronomy (but took it at Queens, not Penn)! Definitely one of my favorite class‚Ä¶
#
# 633)   Yeah, he sent it to me through a mutual physics prof friend at Caltech/CERN. Very ba‚Ä¶
#
# 634) Just learned that my physics prof from Penn is head of Fermilab &amp; still has some of my old homework <U+263A><U+FE0F>
#
# 635) 147 It is unfortunately common for many in academia to overweight the value of ideas &amp; underweight bringing‚Ä¶
#
# 636) _Enough People read too much into this level of detail. It‚Äôs not useful for predicting the future, nor can‚Ä¶
#
# 637) _Enough Critical feedback is always appreciated btw
#
# 638)    A nightcap would probably work best
#
# 639)   Pretty much
#
# 640) _com Good summary
#
# 641)     Testing with shorter RVac skirt went well. Full length skirt test coming soon.
#
# 642)  Good chance something will slip, but, yeah, Sunday is intense
#
# 643)  They‚Äôre quite accurate!
#
# 644)  That number sure comes up a lot <U+0001F923><U+0001F923>
#
# 645)  15 I‚Äôm fine with reasonable drone footage. Just needs to be at a fair distance &amp; not coming r‚Ä¶
#
# 646)   Thanks to a smart and hardworking team at Tesla. These sure are wild times ‚Ä¶
#
# 647)   Brave Starhopper carried the day
#
# 648)  Only so many days
#
# 649)  We were too obtuse for our own good, although I think it works esthetically. Those are folded-over c‚Ä¶
#
# 650)  But actually nothing. Was surprised to hear they‚Äôre across the road. Adding silicon to carbon anode‚Ä¶
#
# 651) The Big Bang started very, very smol
#
# 652) Should we believe things proportionate to the evidence that they are true? (yes)
#
# 653)   Was just there &amp; weather was calm. Sure hope it stays that way!
#
# 654)  Exactly
#
# 655)   No, we‚Äôre focused on developing new products &amp; scaling production
#
# 656)   Yes, will show V2. Still far from LASIK, but could get pretty close in a few years.
#
# 657) Live webcast of working  device
# Friday 3pm Pacific
#
# 658)   Very different computers are needed for training vs inference. FSD is mostly Int8, but Dojo is‚Ä¶
#
# 659)   Not exactly GPUs for NN. Lots of cores optimized for dot products with fast local memory &amp; sup‚Ä¶
#
# 660)  Yeah. Occasional flights from land are ok, but frequent (daily) flights probably need ~30km / 18 m‚Ä¶
#
# 661)   Sure
#
# 662) 23life I tried to warn them, but they just dug their own grave twice as fast!
#
# 663)  400 Wh/kg *with* high cycle life, produced in volume (not just a lab) is not far. Probably 3 to 4 years.
#
# 664)  Starship/Super Heavy, which is ~10X mass of Zenit, will mostly launch from ocean spaceports long-term
#
# 665) _com Accurate distance calculation using only vision is fundamental. Other sensors can help, but are not fundamental.
#
# 666) More fun games coming soon to ur Tesla
#
# 667) New Tesla feature coming that enables your car to play snake jazz or Polynesian elevator music through its outside speakers wherever you go
#
# 668)  Or a self-perpetuating autocracy based on a farcical aquatic ceremony where the king is chosen by a wise panzer in a lake
#
# 669)  Direct democracy. Short, comprehensible laws voted on directly by the people.
# Snake Jazz.
#
# 670)   True <U+0001F923><U+0001F923>
#
# 671)   _ai _com Absolutely needs liquid cooling. We‚Äôre applying our experience‚Ä¶
#
# 672)    Almost never need to replace whole engine, but some individual parts like‚Ä¶
#
# 673)   3 Mostly for employees, but we‚Äôll support public access whenever it‚Äôs‚Ä¶
#
# 674)   3 Absolutely <U+0001F603> <U+0001F3DD>
#
# 675)  _Bass3d   It‚Äôs counter-intuitive, but Raptor has so much thrust at h‚Ä¶
#
# 676)  3   Yes, it will have huge nuts haha
#
# 677)  We really need a bigger one, so adults can squeeze in too. Guaranteed to make a party more fun. Works well with flamethrowers!
#
# 678) 3   My favorite is one in tension, other DoF in compression. New Roadster w‚Ä¶
#
# 679) Aloha, welcome back from space <U+0001F4AB>
#
# 680) _mitka  Winning ‚Äúworst person I‚Äôve ever worked with‚Äù is not easy. Some real champions are vying for that title!
#
# 681) : Falcon 9‚Äôs first stage has landed on the Of Course I Still Love You droneship ‚Äì first time a booster has completed six flights!‚Ä¶
#
# 682)  Humans are swiftly becoming a small percentage of total compute
#
# 683) _Bass3d    Very impressive render. Note, legs will be bigger &amp; there‚Äô‚Ä¶
#
# 684) _sci Also, there could be long period comets that intersect Earth right now. We just haven‚Äôt observed the‚Ä¶
#
# 685) _sci Pretty much
#
# 686)   Wow
#
# 687)  That‚Äôs a great one
#
# 688)  Bold move, sir, bold move
#
# 689)    Thank you, Tesla is most honored!
#
# 690)   Very real possibility
#
# 691) History is written by the victors ‚Ä¶ except on Wikipedia haha
#
# 692)  Yes. Probably more accurate to say Great Filters plural.
#
# 693) We must pass The Great Filter
#
# 694) Sounds right
#
# 695) A truly useful exaflop at de facto FP32
#
# 696)  _feed Metal has a fudge-like consistency near its melting point, so you can just smoosh it together
#
# 697) _Enough   Your insights over the years have been excellent. That‚Äôs approximately right.
#
# 698)  Absolutely, but it doesn‚Äôt seem that govt can move fast enough
#
# 699)  Ok
#
# 700)  It will blow ur mind haha
#
# 701) Our main engineering locations are Palo Alto, Austin &amp; Seattle, but working remotely is acceptable for exceptional candidates
#
# 702) Great mission patch design!
#
# 703) _Truth Haha true
#
# 704)   Exactly
#
# 705)    Also definitely coming haha. Will only be on relatively recent cars,‚Ä¶
#
# 706) @_bennettm_  Yes! We‚Äôre labeling bumps &amp; potholes, so the car can slow down or steer around them when safe to do so.
#
# 707)   Not perfectly at first, but yes. Will take maybe a year or so to get really good at‚Ä¶
#
# 708)  More software improvements coming
#
# 709)  Significant improvements coming to S/X air suspension soon via software update! Will simultaneously‚Ä¶
#
# 710)  H2O, CH4/CO2, N2, iron, nickel, chrome, aluminum (not necessarily in that order) will matter far m‚Ä¶
#
# 711) 27  The rate of improvement from original GPT to GPT-3 is impressive. If this rate of improvement‚Ä¶
#
# 712) : NEWS:  &amp;  are targeting no earlier than Oct. 23 for Crew Dragon‚Äôs first operational mission to the _S‚Ä¶
#
# 713)  Impressive
#
# 714)  This is important
#
# 715)  Nobody would suggest buying airplanes that only fly once &amp; then crash into the ocean. That would be absurd ‚Ä¶
#
# 716) _com I generally try my best not to be on patents
#
# 717)  Will be amazing to see it in operation! Biggest casting machine ever made. Will make rear body in a‚Ä¶
#
# 718)  Aiming to make it super fun!
#
# 719) SN7 will be new alloy test tank taken to burst pressure. SN8 will have body flaps &amp; nosecone.
#
# 720) _Goldberg_  Note the fabulous plaid jacket &amp; gingham shirt combo <U+0001F923>
#
# 721)  Clearly
#
# 722) : Spot the tiny humans!!! This shot really puts it into scale!!! A full blown Starship and SuperHeavy will be hard to fat‚Ä¶
#
# 723)     Also true
#
# 724)  And why aim your attacks at Tesla, when we‚Äôre doing more than any other company on Earth to advance‚Ä¶
#
# 725) 4NYGov  Good analysis. He also includes a govt loan for high efficiency vehicles that Tesla paid b‚Ä¶
#
# 726)   _max  Yeah, full name of engine is Velociraptor or Raptor for short
#
# 727)   _max  Haha, good catch. Booster will have fixed legs that add ~2m in height.
#
# 728)     Ok
#
# 729)   Apart from failing to quarantine elderly/at-risk people early (a mistake they recognize), they were right
#
# 730) Good piece on Giga Berlin construction
#
# 731) : Falcon 9‚Äôs first stage has landed on the Of Course I Still Love You droneship
#
# 732)  This is gonna be great
#
# 733)    We‚Äôll do several short hops to smooth out launch process, then go high altitude with body flaps
#
# 734)   V1.1 legs will be ~60% longer. V2.0 legs will be much wider &amp; taller ‚Äî like Falcon, bu‚Ä¶
#
# 735)  Exactly
#
# 736) 45 Mars is looking real
#
# 737)  Most likely
#
# 738)    True
#
# 739)  True fact
#
# 740)   For sure
#
# 741) _feed Pretty much
#
# 742)  Nosecone closing is recommended, but not required, for safe entry
#
# 743) : "To anybody who has touched Endeavour, you should take a moment to just cherish this day."
#
# Touching words from _Doug as @‚Ä¶
#
# 744)  Space is the new air
#
# 745) : LIVE: An update on today's  Dragon Endeavour splashdown, returning  &amp; _Doug home to Earth. Hear from ‚Ä¶
#
# 746) : UPDATE: Post-SpaceX Crew Dragon DM-2 Splashdown News Conference no earlier than 4:45pm ET. Watch live:
#
# 747) Congratulations  &amp;  on completing first crewed Dragon flight!! <U+0001F1FA><U+0001F1F8> returned.
#
# 748) : Good splashdown of Dragon confirmed! Welcome back to Earth,  and _Doug!
#
# 749) Dragon will travel from south of New Zealand to Florida in ~37 minutes
#
# 750) Coming in hot
#
# 751)   All correct. Parachutes were originally the backup landing system, with SuperDraco thruster‚Ä¶
#
# 752) 1028  _Station  _Doug Great game
#
# 753)    _Win Working on it
#
# 754) _Crew: ._Doug &amp;  will spend one more night in space prior to returning to their homeland, Earth.
#
# While as‚Ä¶
#
# 755) : Separation confirmed. Dragon performing 4 departure burns to move away from the _Station
#
# 756)  The simplest solution is not necessarily the most satisfying
#
# 757) The Great Pyramid was the tallest structure made by humans for 3800 years. Three thousand, eight hundred years.
#
# 758)  So true
#
# 759)  Ancient Egypt had an incredible esthetic that stands to this day
#
# 760) _feed Engineering is magic made real
#
# 761)  Cool
#
# 762) Starship SN5 just completed full duration static fire. 150m hop soon.
#
# 763) 74    _Skeptic Not that I‚Äôm aware of
#
# 764)    _Skeptic Yes. Could also extend range of hearing beyond normal frequencies and amplitudes. Deus Ex.
#
# 765)   _Skeptic Neuralinks are currently meant for mature brains &amp; functionality is lost if remo‚Ä¶
#
# 766)   _LSP Congrats on a great launch!
#
# 767) 56367384    Adagio for Strings is great
#
#
# 768)   Mein Herz Brennt. Best boss battle song ever.
#
# 769)  One of the all time best
#
# 770)  Sure
#
# 771) Sure could use a good rave
# What‚Äôs your favorite techno
#
# 772) The rumor that Bill Gates &amp; I are lovers is completely untrue
#
# 773) 31345919  We‚Äôve been working on this for about 4 years. Originally meant for rabies vaccine, but it‚Ä¶
#
# 774)   Thanks for letting me know. Will dig into it.
#
# 775)  _aw _  The government has the most money by far. They talk in trillions.
#
# 776) 305  Haha no one can ever have our top secret fart technology!!
#
# 777) _lopezXx  Sure
#
# 778)    Haha
#
# 779)   Maybe he‚Äôs feeling the bern haha
#
# 780)  I was just out at the launch pad. Connector damaged in the storm, but fixed now. Might be able to‚Ä¶
#
# 781)  Sounds great
#
# 782) _nafnlaus  Haha
#
# 783) 17 What I like most is their great sense of humor
#
# 784)   Exactly
#
# 785)  Once an Onion, now a Rose
#
# 786)   Wow, you think about me a lot!
#
# 787)  Haha
#
# 788) : Pick up the energetic wallpapers, and charge your everyday adventure!
#
# 789) Almost a decade ago. Original Dragon in background.
#
# 790)  Fair point! Will discuss with team.
#
# 791)  He was amazing
#
# 792) Great song
#
#
# 793)  That‚Äôs me! Haha
#
# 794)  This has a lot of potential. Lithium is pretty much everywhere.
#
# 795)  Whoa cool
#
# 796)    Has to be blue steel :)
#
# 797)   We need high Brinell hardness &amp; high corrosion resistance. Because of Cybertruck‚Äôs faceted‚Ä¶
#
# 798)    I really want to do this! Will be great fun. Could be both LA and Austin.
#
# 799)  Cool
#
# 800) _TeslaPhx @28delayslater  7 _benton 4tesla Not impossible
#
# 801) : NEW VIDEO - Why Tesla Model Y is Their Most Important Car! [Auto Focus Ep 5]
#
#
#
# 802)   The song I whistle most is Strangers in the Night
#
# 803)  Great song
#
# 804)    Haha thanks Kara :)
#
# 805)   For sure
#
# 806) _MorenoS  Exactly!
#
# 807) Cool Model 3 review by
#
# 808)  Yeah, would have been way better just to send everyone $6k
#
# 809) These are jammed to gills with special interests earmarks. If we do a stimulus at all, it should just be direct payments to consumers.
#
# 810)  Pretty much
#
# 811) Goal of government should be to maximize the happiness of the people. Giving each person money allows them to decid‚Ä¶
#
# 812) Another government stimulus package is not in the best interests of the people imo
#
# 813)   Something fun is coming
#
# 814) 13031925    Could be great!
#
# 815)   That‚Äôs a great idea!
#
# 816)  We are actually looking for revolutionary actuaries for Tesla Insurance! Please inquire, if interested.
#
# 817)  Retail investors like  are remarkably insightful. Also, .
#
# 818)  Especially for boost stage, which is volumetrically constrained, CH4 is way better than H2. Soviet CH4‚Ä¶
#
# 819)   Absolutely
#
# 820)  Haha
#
# 821) Impressive Tianwen-1 Mars rover mission launched by China today
#
# 822) _Future Good article
#
# 823)  Good point
#
# 824)  Human overseen at first, then fully self-driving
#
# 825)  We need to finish upgrading Autopilot to 4D vs ~2.5D, then it will go up very steep slopes
#
# 826) Nothing has gaslit more people than the movie Gaslight
#
# 827)  Great shot!
#
# 828)    Will attempt to fly later this week
#
# 829) _myneni    Sound &amp; flame color will be quite different
#
# 830)  At some point, we should probably do advertising as art/communication/entertainment &amp; to support high quality media
#
# 831)   _AA_Carmack It‚Äôs almost right
#
# 832)  _AA_Carmack We talked about an hour ago. He seems fine.
#
# 833)  Better to put the money into the product than sales &amp; marketing!
#
# 834) : Falcon 9‚Äôs first stage has landed on the Just Read the Instructions droneship
#
# 835)  Nice work, SpaceX team!
#
# 836)   _Doug  Still long way to go. Reuse only matters to degree that it‚Äôs rapid &amp; complete.
#
# 837)   New deep crimson from Giga Berlin is my favorite
#
# 838)  Important to service very high latitudes
#
# 839)  True, the 2012 Model S is still a great car. Was driving SN28 a few months ago and driving feel wa‚Ä¶
#
# 840) : Tesla's Model 3 received top marks from safety organizations in North America, Europe, and Australia
#
# 841)  This looks cool
#
# 842)   6Manny     Good article. I‚Ä¶
#
# 843)  Some contribute more. Y chromosome &amp; mitochondria are constant, except for mutations.
#
# 844)  Fermi was awesome. He understood the right questions to ask.
#
# 845) 4ttwegner  How come Hulk never loses pants!?
#
# 846)  No prior neuroscience background is required. This is primarily an electrical/electronic (chip design)/me‚Ä¶
#
# 847)  Many
#
# 848)  Summarizes pretty much every biz school case study
#
# 849)   Pretty much
#
# 850)  We better hustle with Neuralink. Not moving fast enough.
#
# 851) Thanks
#
# 852) _ _feed Gigafactory is the product even more than the car
#
# 853)   Sure
#
# 854)   Trying to set a good example haha. Mars needs people!
#
# 855)  Great work by Tesla software engineering
#
# 856)  Ok
#
# 857)    Exactly
#
# 858)      _Group  Mass to orbit is a more accura‚Ä¶
#
# 859)  Cute
#
# 860) 5  16 13031925 _Padival      Wow
#
# 861) 13031925 Wild times!
#
# 862)  We‚Äôre being extra paranoid. Maximizing probability of successful launch is paramount.
#
# 863)  Welcome anytime
#
# 864)  Well, I do care very much about sustainability of civilization, but there is some truth to the irony part haha
#
# 865)  305    Yes, in plan. Superchargers and public high power wall c‚Ä¶
#
# 866) 305   Doing range testing now. Number will be significantly higher than 300. Extreme‚Ä¶
#
# 867)    It may be able to reach 250kW at low states of charge
#
# 868)  Thanks :)
#
# 869)  I didn‚Äôt mind DA2. DA1 was awesome. Mass Effect 2 (talking about sequels) is amazing.
#
# 870)  Haha
#
# 871) I spoke with Korolev‚Äôs family today.
# He was one of the very best.
# <U+041A><U+043E><U+0440><U+043E><U+043B><U+044C><U+043E><U+0432> / <U+041A><U+043E><U+0440><U+043E><U+043B><U+0451><U+0432>.
#
# 872) _Afshari In general, we need to improve how podcasts play
#
# 873)   True haha
#
# 874) 3slaguy    Earning power post augmentation would easily pay for itself (if that‚Äô‚Ä¶
#
# 875)    Absolutely
#
# 876)    Probably a good one to design &amp; engineer in Germany
#
# 877) _bnd   Even more
#
# 878)    Ok
#
# 879)  True
#
# 880) Wow, IHOP &amp; GitHub are close
#
# 881) Best use of the term ‚ÄúFull Stack‚Äù?
#
# 882)   For sure. This is both great &amp; terrifying. Everything we‚Äôve ever sensed or thought has been‚Ä¶
#
# 883)  No easy way to answer this in a tweet, but helping with dire brain injuries is our first priority. Details Aug 28.
#
# 884)  True, it sounds so surreal, but the negative propaganda is still all out there &amp; easy to find in social me‚Ä¶
#
# 885)  Make sure to read ur terms &amp; conditions before clicking accept!

# %%
# Plotting 
plt.figure(figsize=(8,6)) 
for i in range(0, df.shape[0]):
  plt.scatter(df["Polarity"][i], df["Subjectivity"][i], color='Blue') 
# plt.scatter(x,y,color)   
plt.title('Sentiment Analysis') 
plt.xlabel('Polarity') 
plt.ylabel('Subjectivity') 
plt.show()

# %%
# Print the percentage of positive tweets
ptweets = df[df.Analysis == 'Positive']
ptweets = ptweets['Text']
ptweets
round( (ptweets.shape[0] / df.shape[0]) * 100 , 1)
# Out:
# 44.3

# %%
# Print the percentage of negative tweets
ntweets = df[df.Analysis == 'Negative']
ntweets = ntweets['Text']
ntweets
round( (ntweets.shape[0] / df.shape[0]) * 100, 1)
# Out:
# 10.8

# %%
# Show the value counts
df['Analysis'].value_counts()
# Out:
# Neutral     899
# Positive    885
# Negative    215
# Name: Analysis, dtype: int64

# %%
# Plotting and visualizing the counts
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind = 'bar')
plt.show()
